# %% [markdown]
# TÍTULOS DISPONÍVEIS NA NETFLIX

# %%
#importar as bibliotecas
#por convenção chamar as bibliotecas pandas "pd"

# %%
import pandas as pd

#carregar o arquivo csv
#o pandas converte o arquivo em DataFrame "df"

#fazer uma leitura da planilha organizada de dados (DataFrame)

df = pd.read_csv('netflix_titles.csv')
df.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.count()
# Out:
# show_id         7787
# type            7787
# title           7787
# director        5398
# cast            7069
# country         7280
# date_added      7777
# release_year    7787
# rating          7780
# duration        7787
# listed_in       7787
# description     7787
# dtype: int64

# %%
#descreve as colunas
df.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#mostrar tipos de dados que há em cada coluna do df
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Quantos títulos há na planilha
df['title'].value_counts()
# Out:
# An Interview with God    1
# For Colored Girls        1
# Naa Bangaaru Talli       1
# The Governor             1
# Aussie Gold Hunters      1
#                         ..
# Pocoyo & Cars            1
# IBOY                     1
# Borgen                   1
# Indiscretion             1
# The Confession Killer    1
# Name: title, Length: 7787, dtype: int64

# %%
#Quantas vezes há cada país na planilha
df['country'].value_counts()
# Out:
# United States                                                      2555
# India                                                               923
# United Kingdom                                                      397
# Japan                                                               226
# South Korea                                                         183
#                                                                    ...
# Canada, Norway                                                        1
# United States, France, Serbia                                         1
# India, Turkey                                                         1
# France, Switzerland, Spain, United States, United Arab Emirates       1
# United States, France, Canada, Belgium                                1
# Name: country, Length: 681, dtype: int64

# %%
#Mostrando dados em um gráfico
#Informar que a visualização será no próprio notebook, não sendo necessária a 
#importação das bibliotecas
# %matplotlib inline
#mostrando em gráfico de barras os países da planilha

df['country'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_country = df[df['country']=='South Korea'].value_counts().plot.bar()

# %%
#Mostrando dados em um gráfico
#Informar que a visualização será no próprio notebook, não sendo necessária a 
#importação das bibliotecas
# %matplotlib inline
#mostrando em gráfico de barras os tipos de títulos da planilha

df['type'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#listar os tipos 
df['type'].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
#listar os anos dos títulos
df['release_year'].unique()
# Out:
# array([2020, 2016, 2011, 2009, 2008, 2019, 1997, 2017, 2018, 2014, 2015,
#        2010, 2005, 2013, 2012, 2006, 2000, 2003, 1989, 2004, 1977, 1971,
#        1993, 2007, 1998, 1988, 1996, 2002, 1986, 1990, 1979, 1980, 1974,
#        2001, 1999, 1966, 1991, 1982, 1994, 1995, 1978, 1992, 1972, 1975,
#        2021, 1973, 1967, 1960, 1981, 1958, 1976, 1968, 1956, 1985, 1965,
#        1984, 1983, 1987, 1945, 1946, 1962, 1925, 1942, 1969, 1955, 1963,
#        1964, 1954, 1970, 1944, 1947, 1959, 1943])

# %%
#Mostrando dados em um gráfico
#Informar que a visualização será no próprio notebook, não sendo necessária a 
#importação das bibliotecas
# %matplotlib inline
#mostrando em gráfico de barras os anos dos títulos da planilha

df['release_year'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Quantas títulos por ano
df['release_year'].value_counts()
# Out:
# 2018    1121
# 2017    1012
# 2019     996
# 2016     882
# 2020     868
#         ...
# 1966       1
# 1947       1
# 1959       1
# 1964       1
# 1925       1
# Name: release_year, Length: 73, dtype: int64

# %%
df['release_year'].unique()
# Out:
# array([2020, 2016, 2011, 2009, 2008, 2019, 1997, 2017, 2018, 2014, 2015,
#        2010, 2005, 2013, 2012, 2006, 2000, 2003, 1989, 2004, 1977, 1971,
#        1993, 2007, 1998, 1988, 1996, 2002, 1986, 1990, 1979, 1980, 1974,
#        2001, 1999, 1966, 1991, 1982, 1994, 1995, 1978, 1992, 1972, 1975,
#        2021, 1973, 1967, 1960, 1981, 1958, 1976, 1968, 1956, 1985, 1965,
#        1984, 1983, 1987, 1945, 1946, 1962, 1925, 1942, 1969, 1955, 1963,
#        1964, 1954, 1970, 1944, 1947, 1959, 1943])

# %%
df['release_year'].value_counts().plot.barh(title='Ano')
# Out:
# <AxesSubplot:title={'center':'Ano'}>

# %%
#tamanho
df.shape
# Out:
# (7787, 12)

# %%
#tipos de dados das colunas
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Análise matemátuca das colunas numéricas
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
#quantidade listada
df['listed_in'].value_counts()
# Out:
# Documentaries                                                             334
# Stand-Up Comedy                                                           321
# Dramas, International Movies                                              320
# Comedies, Dramas, International Movies                                    243
# Dramas, Independent Movies, International Movies                          215
#                                                                          ...
# British TV Shows, International TV Shows, Stand-Up Comedy & Talk Shows      1
# Classic Movies, Comedies, Romantic Movies                                   1
# Classic & Cult TV, Crime TV Shows, TV Dramas                                1
# Crime TV Shows, TV Action & Adventure, TV Sci-Fi & Fantasy                  1
# Action & Adventure, Anime Features, Horror Movies                           1
# Name: listed_in, Length: 492, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: rating, dtype: int64

# %%
df[df['release_year'] == df['release_year'].max()]
# Out:
#      show_id     type                                              title  \
# 980     s981  TV Show                                       Bling Empire
# 1222   s1223  TV Show                                    Carmen Sandiego
# 1285   s1286    Movie                                           Charming
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 1440   s1441  TV Show                                          Cobra Kai
# 1514   s1515    Movie            Crack: Cocaine, Corruption & Conspiracy
# 1528   s1529    Movie                        Creating The Queen's Gambit
# 1780   s1781  TV Show                                     Disenchantment
# 1864   s1865  TV Show                                Dream Home Makeover
# 2327   s2328  TV Show                                  Gabby's Dollhouse
# 2672   s2673  TV Show                      Headspace Guide to Meditation
# 2741   s2742  TV Show                                              Hilda
# ...

# %%
df[df['release_year'] == df['release_year'].min()]
# Out:
#      show_id     type                              title director cast  \
# 4867   s4868  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country         date_added  release_year rating  duration listed_in  \
# 4867     NaN  December 30, 2018          1925  TV-14  1 Season  TV Shows
#
#                                             description
# 4867  This collection restores films from women who ...

# %%
df[df['release_year'] == df['release_year'].max()][['type','date_added']]
# Out:
#          type         date_added
# 980   TV Show   January 15, 2021
# 1222  TV Show   January 15, 2021
# 1285    Movie    January 8, 2021
# 1355    Movie   January 12, 2021
# 1440  TV Show    January 1, 2021
# 1514    Movie   January 11, 2021
# 1528    Movie    January 8, 2021
# 1780  TV Show   January 15, 2021
# 1864  TV Show    January 1, 2021
# 2327  TV Show    January 5, 2021
# 2672  TV Show    January 1, 2021
# 2741  TV Show  December 14, 2020
# 2753  TV Show    January 5, 2021
# 3018  TV Show    January 8, 2021
# 3822  TV Show    January 8, 2021
# 4086  TV Show    January 8, 2021
# 4173  TV Show    January 1, 2021
# 4390  TV Show    January 5, 2021
# 4468  TV Show   January 13, 2021
# 4710    Movie   January 15, 2021
# 4965  TV Show    January 8, 2021
# 5103    Movie    January 6, 2021
# 5859    Movie    January 8, 2021
# 5921  TV Show    January 6, 2021
# 6477  TV Show    January 8, 2021
# 6670    Movie    January 1, 2021
# 6701  TV Show    January 2, 2021
# ...

# %%
df.loc[df.groupby('duration')['release_year'].idxmax()]
# Out:
#      show_id     type                                              title  \
# 980     s981  TV Show                                       Bling Empire
# 3592   s3593  TV Show                 LEGO Ninjago: Masters of Spinjitzu
# 463     s464    Movie   American Factory: A Conversation with the Obamas
# 910     s911    Movie                       Bigflo & Oli: Hip Hop Frenzy
# 57       s58    Movie                                         100% Halal
# ...      ...      ...                                                ...
# 512     s513    Movie                              Anelka: Misunderstood
# 7220   s7221    Movie                      Tribhanga - Tedhi Medhi Crazy
# 5859   s5860    Movie                                        Stuck Apart
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 27       s28    Movie                                             #Alive
#
#                            director  \
# 980                             NaN
# ...

# %%
#títulos disponíveis entre os anos 2000 e 2002
df[(df['release_year']>2000) & (df['release_year']<2002)]
# Out:
#      show_id     type                                              title  \
# 431     s432    Movie                                Along Came a Spider
# 517     s518    Movie                                         Angel Eyes
# 599     s600    Movie                                              Asoka
# 709     s710    Movie                                Balto 2: Wolf Quest
# 811     s812  TV Show                                 Behind Enemy Lines
# 951     s952    Movie                                    Black Hawk Down
# 993     s994    Movie                                               Blow
# 1029   s1030    Movie                                  Bollywood Calling
# 1757   s1758    Movie                                     Dil Chahta Hai
# 2053   s2054    Movie                                          Evolution
# 2064   s2065    Movie                                        Exit Wounds
# 2502   s2503    Movie                                       Gosford Park
# ...

# %%
#Inserindo imagem
print('Gráfico dos maiores sucessos da Netflix')
from IPython.display import Image
Image('grafico_netflix.jpg')
# Out:
# Gráfico dos maiores sucessos da Netflix

# %%
print('Top 10 da Netflix')
from IPython.display import Image
Image('top10_brasil.jpg')
# Out:
# Top 10 da Netflix

# %%
print('Ranking dos países com mais maratonistas')
from IPython.display import Image
Image('grafico_paises_maratonistas.png')
# Out:
# Ranking dos países com mais maratonistas

# %%
#Importando os módulos
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

df = pd.read_csv('netflix_titles.csv')
df.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['type'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# 1 Season     1608
# 2 Seasons     382
# 3 Seasons     184
# 90 min        136
# 93 min        131
#              ...
# 224 min         1
# 228 min         1
# 191 min         1
# 200 min         1
# 205 min         1
# Name: duration, Length: 216, dtype: int64

# %%
df['listed_in'].value_counts()
# Out:
# Documentaries                                           334
# Stand-Up Comedy                                         321
# Dramas, International Movies                            320
# Comedies, Dramas, International Movies                  243
# Dramas, Independent Movies, International Movies        215
#                                                        ...
# Dramas, Faith & Spirituality, Independent Movies          1
# Action & Adventure, Sports Movies                         1
# Romantic TV Shows, TV Action & Adventure, TV Dramas       1
# Action & Adventure, Classic Movies, Sci-Fi & Fantasy      1
# Action & Adventure, Documentaries, Sports Movies          1
# Name: listed_in, Length: 492, dtype: int64

# %%
df['date_added'].value_counts()
# Out:
# January 1, 2020      118
# November 1, 2019      94
# March 1, 2018         76
# December 31, 2019     76
# October 1, 2018       72
#                     ...
# December 25, 2015      1
# April 17, 2016         1
# February 16, 2014      1
# December 9, 2015       1
#  August 21, 2017       1
# Name: date_added, Length: 1565, dtype: int64

# %%
#Importando bibliotecas
import pandas as pd
import matplotlib as mat
import matplotlib.pyplot as plt
import numpy as np
import colorsys
plt.style.use('seaborn-talk')
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

df = pd.read_csv('netflix_titles.csv')

# %%
#Gerando um histograma
df.type.hist()
plt.xlabel("Tipo")
plt.ylabel("Quantidade")
plt.title("Histograma")
plt.show()

# %%
df.release_year.hist()
plt.xlabel("Ano")
plt.ylabel("Quantidade")
plt.title("Histograma")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
#Gerando automaticamente um índice sequencial para cada linha do arquivo
#que começa em 0 e vai sendo incrementado de 1 em 1 até sua última linha.
#Qualquer coluna pode ser definida como índice, quano utilizado o parâmetro set_index,
#na coluna desejada
#Usar inplace=True para realizar a mudança


df.set_index('show_id',inplace=True)
df.head(10)
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
# s6       TV Show     46        Serdar Akar
# s7         Movie    122    Yasir Al Yasiri
# s8         Movie    187     Kevin Reynolds
# s9         Movie    706      Shravan Kumar
# s10        Movie   1920       Vikram Bhatt
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
#Verificando colunas com df.columns que retorna todas as colunas do DataFrame
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
O df.values retorna um array numpy (pacote do python que suporta matrizes multidimensionais)

# %%
df.values
# Out:
# array([['TV Show', '3%', nan, ..., '4 Seasons',
#         'International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#         'In a future where the elite inhabit an island paradise far from the crowded slums, you get one chance to join the 3% saved from squalor.'],
#        ['Movie', '7:19', 'Jorge Michel Grau', ..., '93 min',
#         'Dramas, International Movies',
#         'After a devastating earthquake hits Mexico City, trapped survivors from all walks of life wait to be rescued while trying desperately to stay alive.'],
#        ['Movie', '23:59', 'Gilbert Chan', ..., '78 min',
#         'Horror Movies, International Movies',
#         "When an army recruit is found dead, his fellow soldiers are forced to confront a terrifying secret that's haunting their jungle island training camp."],
#        ...,
#        ['Movie', 'Zulu Man in Japan', nan, ..., '44 min',
#         'Documentaries, International Movies, Music & Musicals',
# ...

# %%
df.loc['s10']
# Out:
# type                                                        Movie
# title                                                        1920
# director                                             Vikram Bhatt
# cast            Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# country                                                     India
# date_added                                      December 15, 2017
# release_year                                                 2008
# rating                                                      TV-MA
# duration                                                  143 min
# listed_in          Horror Movies, International Movies, Thrillers
# description     An architect and his wife move into a castle t...
# Name: s10, dtype: object

# %%
df.loc[['s2'],['cast']]
# Out:
#                                                       cast
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...

# %%
df.loc[['s25'],['type','country']]
# Out:
#             type country
# show_id
# s25      TV Show   Japan

# %%
#Definindo [start:stop] com df.loc slice
df.loc['s30':'s40']
# Out:
#             type                title               director  \
# show_id
# s30      TV Show             #blackAF                    NaN
# s31        Movie     #cats_the_mewvie       Michael Margolis
# s32        Movie    #FriendButMarried          Rako Prijanto
# s33        Movie  #FriendButMarried 2          Rako Prijanto
# s34        Movie         #realityhigh       Fernando Lebrija
# s35        Movie                #Roxy        Michael Kennedy
# s36        Movie            #Rucker50  Robert McCullough Jr.
# s37        Movie              #Selfie         Cristina Jacob
# s38        Movie           #Selfie 69         Cristina Jacob
# s39      TV Show  แผนร้ายนายเจ้าเล่ห์                    NaN
# s40        Movie       ¡Ay, mi madre!            Frank Ariza
#
#                                                       cast        country  \
# show_id
# s30      Kenya Barris, Rashida Jones, Iman Benson, Genn...  United States
# ...

# %%
df.loc['s1':'s10':2]
# Out:
#             type  title         director  \
# show_id
# s1       TV Show     3%              NaN
# s3         Movie  23:59     Gilbert Chan
# s5         Movie     21   Robert Luketic
# s7         Movie    122  Yasir Al Yasiri
# s9         Movie    706    Shravan Kumar
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# s9       Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s3       December 20, 2018          2011      R     78 min
# ...

# %%
df.loc['s50':]
# Out:
#             type                                    title           director  \
# show_id
# s50        Movie                           10 jours en or  Nicolas Brossette
# s51        Movie                              10,000 B.C.    Roland Emmerich
# s52      TV Show                       100 Days My Prince                NaN
# s53        Movie                     100 Days Of Solitude                NaN
# s54      TV Show                               100 Humans                NaN
# ...          ...                                      ...                ...
# s7783      Movie                                     Zozo        Josef Fares
# s7784      Movie                                   Zubaan        Mozez Singh
# s7785      Movie                        Zulu Man in Japan                NaN
# s7786    TV Show                    Zumbo's Just Desserts                NaN
# s7787      Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
# ...

# %%
df.loc['s1':'s10',['type','director','country']]
# Out:
#             type           director        country
# show_id
# s1       TV Show                NaN         Brazil
# s2         Movie  Jorge Michel Grau         Mexico
# s3         Movie       Gilbert Chan      Singapore
# s4         Movie        Shane Acker  United States
# s5         Movie     Robert Luketic  United States
# s6       TV Show        Serdar Akar         Turkey
# s7         Movie    Yasir Al Yasiri          Egypt
# s8         Movie     Kevin Reynolds  United States
# s9         Movie      Shravan Kumar          India
# s10        Movie       Vikram Bhatt          India

# %%
#Consultando com o query
df.query('release_year <1998').head()
# Out:
#           type                title              director  \
# show_id
# s8       Movie                  187        Kevin Reynolds
# s106     Movie  300 Miles to Heaven        Maciej Dejczer
# s154     Movie     A Bridge Too Far  Richard Attenborough
# s166     Movie   A Clockwork Orange       Stanley Kubrick
# s167     Movie    A Dangerous Woman    Stephen Gyllenhaal
#
#                                                       cast  \
# show_id
# s8       Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# s106     Krzysztof Stroiński, Andrzej Mellin, Adrianna ...
# s154     Dirk Bogarde, James Caan, Michael Caine, Sean ...
# s166     Malcolm McDowell, Patrick Magee, Michael Bates...
# s167     Debra Winger, Barbara Hershey, Gabriel Byrne, ...
#
#                                country        date_added  release_year rating  \
# show_id
# s8                       United States  November 1, 2019          1997      R
# ...

# %%
df.query('release_year >2001').head()
# Out:
#             type  title           director  \
# show_id
# s1       TV Show     3%                NaN
# s2         Movie   7:19  Jorge Michel Grau
# s3         Movie  23:59       Gilbert Chan
# s4         Movie      9        Shane Acker
# s5         Movie     21     Robert Luketic
#
#                                                       cast        country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#                 date_added  release_year rating   duration  \
# show_id
# s1         August 14, 2020          2020  TV-MA  4 Seasons
# s2       December 23, 2016          2016  TV-MA     93 min
# ...

# %%
df.query('country=="Brazil"').head()
# Out:
#             type                      title                      director  \
# show_id
# s1       TV Show                         3%                           NaN
# s209       Movie           A new Capitalism                           NaN
# s219     TV Show            A Queen Is Born                  Carla Barros
# s321       Movie  Afonso Padilha: Classless  Junior Carelli, Rudge Campos
# s323     TV Show        Afronta! Facing It!               Juliana Vicente
#
#                                                       cast country  \
# show_id
# s1       João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# s209                                                   NaN  Brazil
# s219                         Gloria Groove, Alexia Twister  Brazil
# s321                                        Afonso Padilha  Brazil
# s323     Loo Nascimento, Ingrid Silva, Rincon Sapiência...  Brazil
#
#                 date_added  release_year rating   duration  \
# show_id
# ...

# %%
df.query('release_year >1998 & country=="United States"').head()
# Out:
#           type     title                                director  \
# show_id
# s4       Movie         9                             Shane Acker
# s5       Movie        21                          Robert Luketic
# s11      Movie      1922                            Zak Hilditch
# s15      Movie      3022                              John Suits
# s26      Movie  (T)ERROR  Lyric R. Cabral, David Felix Sutcliffe
#
#                                                       cast        country  \
# show_id
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s11      Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# s15      Omar Epps, Kate Walsh, Miranda Cosgrove, Angus...  United States
# s26                                                    NaN  United States
#
#                 date_added  release_year rating duration  \
# show_id
# ...

# %%
df.query('release_year <2000 | type=="Movie"').head()
# Out:
#           type  title           director  \
# show_id
# s2       Movie   7:19  Jorge Michel Grau
# s3       Movie  23:59       Gilbert Chan
# s4       Movie      9        Shane Acker
# s5       Movie     21     Robert Luketic
# s7       Movie    122    Yasir Al Yasiri
#
#                                                       cast        country  \
# show_id
# s2       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# s3       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# s4       Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# s5       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# s7       Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
#
#                 date_added  release_year rating duration  \
# show_id
# s2       December 23, 2016          2016  TV-MA   93 min
# s3       December 20, 2018          2011      R   78 min
# s4       November 16, 2017          2009  PG-13   80 min
# ...

# %%
df.groupby(by='type').size()
# Out:
# type
# Movie      5377
# TV Show    2410
# dtype: int64

# %%
#usando o df.isnull para substituir o NaN por zero
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
print(max(df.duration))
# Out:
# 99 min

# %%
print(min(df.duration))
# Out:
# 1 Season

# %%
print('Esses dados foram obtidos no endereço:"https://www.kaggle.com/shivamb/netflix-shows" em 20 de Abril de 2021 para realização da atividade de Ciência de Dados')
print('Aluna: Monique Caroline Gonçalves Dias Ramos - 6º semestre DMD')
print('Fim!')
# Out:
# Esses dados foram obtidos no endereço:"https://www.kaggle.com/shivamb/netflix-shows" em 20 de Abril de 2021 para realização da atividade de Ciência de Dados
# Aluna: Monique Caroline Gonçalves Dias Ramos - 6º semestre DMD
# Fim!
